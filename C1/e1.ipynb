# %% [markdown]
# # Select Dataset
# Vous pouvez trouver des ensembles de données pour l'exploration des données dans de nombreux endroits en ligne, tels que Kaggle, https://www.data.gouv.fr/, data.gov , GitHub, ou simplement en effectuant une recherche Google pour "jeu de données pour l'exploration des données". L'important est de trouver un ensemble de données qui vous intéresse et qui vous donne suffisamment de variété dans les types de données pour explorer diverses méthodes d'analyse et de visualisation.
#
#
# À la fin de ce cours, nous utiliserons l'un des ensembles de données que vous avez trouvés pour la prochaine session.

# %% [markdown]
# # Importation des bibliothèques nécessaires

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Télécharger l'ensemble de données
#
# Une fois que vous avez trouvé un ensemble de données qui vous intéresse, vous pouvez le télécharger ou le lire directement depuis un site Web à l'aide de bibliothèques Python comme Pandas.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Importation de l'ensemble de données dans Python
#
# Astuce: Utilisez `read_csv`, `read_excel`, `read_json`.

# %% [markdown]
# # Affichage des cinq premières lignes
# Astuce: Utilisez `head`.

# %% [markdown]
# # Affichage du nombre de lignes et de colonnes
# Astuce: Utilisez `.shape`

# %% [markdown]
# # Affichage des noms des colonnes
# Astuce: Utilisez `.columns`

# %% [markdown]
# # Réorganisation du dataframe pour inclure uniquement certaines colonnes
# Astuce: Utilisez `[]`

# %% [markdown]
# # Affichage du nombre d'éléments uniques pour chaque colonne
# Astuce: Utilisez `.nunique`

# %% [markdown]
# # Sélectionnez une colonne et affichez ses valeurs uniques
# Affichage du nombre d'éléments par élément dans la colonne
# en utilisant `unique` et `value_counts`

# %% [markdown]
# # Réorganisation du dataframe pour inclure uniquement certaines lines
#
# Astuce: Utilisez `.loc`

# %% [markdown]
# # Utilisez de yData-Profiling pour générer un rapport sur votre ensemble de données

# %% [markdown]
# # Analyse exploratoire des données avec visualisations
#
# Pour effectuer une analyse exploratoire des données (EDA) à l'aide de visualisations avec Pandas, nous pouvons utiliser diverses fonctions pour obtenir des informations clés sur nos données
#
#
#
# ## Graphique linéaire
# Astuce: Utilisez `.plot.line(...)`

# %% [markdown]
# ## Graphique à barres
# Astuce: Utilisez `.plot.bar(...)`

# %% [markdown]
# ## Histogramme
# Astuce: Utilisez `.plot.hist(...)`

# %% [markdown]
# ## Diagramme en boîte
# Astuce: Utilisez `.plot.box(...)`
